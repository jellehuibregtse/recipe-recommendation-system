# %% [markdown]
# <p align="center">
#   <h1 align="center">Recipe recommendation system</h1>
#   <h4 align="center">
#     <strong>Jelle Huibregtse</strong> and <strong>Aron Hemmes</strong>
#   </h4>
# </p>
#
# ## The Assignment
# The goal is to ultimately create a personalized recipe recommendation system that learns from the choices of its users.

# %% [markdown]
# ### Loading in some libraries

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.rcParams['figure.figsize'] = 10, 5
# Out:
# /Users/jelle/.pyenv/versions/3.7.10/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Data Cleaning and Aggregation (DCA)
# First, we need to load the datasets from `.csv` to a `DataFrame`, we will name them accordingly. Then show the first 5 rows and some general information per `DataFrame`.
#
#
# ### The ingredient dataset
# The first dataset is the ingredient dataset:

# %%
df_ingredient = pd.read_csv('dataset/ingredient.csv')
# Set the index to ingredient id.
df_ingredient = df_ingredient.set_index('ingredient_id')
df_ingredient.head()
# Out:
#                        category                      name plural
# ingredient_id
# 1                         dairy  1% lowfat cottage cheese    NaN
# 6                         dairy            1% lowfat milk    NaN
# 10             Mexican products    10-inch flour tortilla      s
# 11                      cereals          100% bran cereal    NaN
# 12                        dairy            2% lowfat milk    NaN

# %%
df_ingredient.dtypes
# Out:
# category    object
# name        object
# plural      object
# dtype: object

# %% [markdown]
# Let's get all the rows where `plural` is missing:

# %%
df_ingredient[df_ingredient['plural'].isnull()]
# Out:
#                     category                                 name plural
# ingredient_id
# 1                      dairy             1% lowfat cottage cheese    NaN
# 6                      dairy                       1% lowfat milk    NaN
# 11                   cereals                     100% bran cereal    NaN
# 12                     dairy                       2% lowfat milk    NaN
# 20                  vinegars              aceto balsamico vinegar    NaN
# ...                      ...                                  ...    ...
# 4641                 cereals                       cooked oatmeal    NaN
# 4642           hot beverages              instant coffee granules    NaN
# 4643                  grains       long grain enriched white rice    NaN
# 4644            frozen fruit  frozen grapefruit juice concentrate    NaN
# 4645            frozen fruit       frozen grape juice concentrate    NaN
#
# [2618 rows x 3 columns]

# %% [markdown]
# Let's get all the unique category's this is usefull when you want to filter ingredients.

# %%
unique = df_ingredient.category.unique()
pd.DataFrame(unique, columns=["category"]).head()
# Out:
#            category
# 0             dairy
# 1  Mexican products
# 2           cereals
# 3            breads
# 4  fresh vegetables

# %% [markdown]
# Since, we are builing a recipe recommendation system it is keythat we have the ingredients of the recipes and categories. The latter we can use for the actual recommendation, for example maybe someone doesn't like diary, we can exclude recipes based on ingredients that fall into the category dairy. You make a case for removing the `plural` column, however we'd argue that it might come in handy when we want to visualize a recipe.

# %% [markdown]
# ### The nutrition dataset
# Next, is the nutrition dataset:

# %%
df_nutrition = pd.read_csv('dataset/nutrition.csv')
# Set the index to ingredient id.
df_nutrition = df_nutrition.set_index('recipe_id')
df_nutrition.head()
# Out:
#            protein  carbo  alcohol  total_fat  sat_fat  cholestrl  sodium  \
# recipe_id
# 214           5.47  41.29     0.00      11.53     2.21       1.39  260.78
# 215           5.70  23.75     1.93       1.08     0.58       3.48   46.17
# 216           4.90  26.88     0.00       1.10     0.58       3.46   41.79
# 217           1.77  18.17     0.00       0.21     0.06       0.00   14.01
# 218           1.38  36.63     0.00       5.47     3.46      10.36   50.22
#
#            iron  vitamin_c  vitamin_a  fiber  pcnt_cal_carb  pcnt_cal_fat  \
# recipe_id
# 214        0.81       8.89     586.20   0.87          56.80         35.68
# 215        0.57      13.02    2738.24   0.62          67.38          6.89
# 216        0.37       6.13    1521.10   0.34          78.45          7.24
# 217        0.19       8.79     478.09   0.69          88.98          2.35
# 218        0.66       0.16     229.16   1.05          72.81         24.46
#
#            pcnt_cal_prot  calories
# recipe_id
# 214                 7.53    290.79
# 215                16.17    141.01
# 216                14.30    137.06
# 217                 8.67     81.70
# 218                 2.73    201.23

# %%
df_nutrition.dtypes
# Out:
# protein          float64
# carbo            float64
# alcohol          float64
# total_fat        float64
# sat_fat          float64
# cholestrl        float64
# sodium           float64
# iron             float64
# vitamin_c        float64
# vitamin_a        float64
# fiber            float64
# pcnt_cal_carb    float64
# pcnt_cal_fat     float64
# pcnt_cal_prot    float64
# calories         float64
# dtype: object

# %% [markdown]
# The data types seem to be correct. Furthermore, for someone concerned with health, we can use each of these datapoints to get a better recommendation. Say someone does not want alcohol in their recipe, we can filter recipes without alcohol:

# %%
df_nutrition_without_alcohol = df_nutrition[df_nutrition['alcohol'] == 0.00]
df_nutrition_without_alcohol['alcohol'].to_frame().head()
# Out:
#            alcohol
# recipe_id
# 214            0.0
# 216            0.0
# 217            0.0
# 218            0.0
# 220            0.0

# %% [markdown]
# Now, we have all recipes without alcohol!

# %% [markdown]
# ### The quantity dataset
# Next, is the quantity dataset:

# %%
df_quantity = pd.read_csv('dataset/quantity.csv')
# Set the index to ingredient id.
df_quantity = df_quantity.set_index('quantity_id')
df_quantity.head()
# Out:
#              recipe_id  ingredient_id  max_qty  min_qty         unit  \
# quantity_id
# 1                  214           1613     2.00     2.00       cup(s)
# 2                  214           3334     0.25     0.25       cup(s)
# 3                  214           2222     0.50     0.50       cup(s)
# 4                  214           2797     0.25     0.25       cup(s)
# 5                  214           3567     3.00     3.00  teaspoon(s)
#
#             preparation  optional
# quantity_id
# 1                   NaN     False
# 2                   NaN     False
# 3                melted     False
# 4              or water     False
# 5                   NaN     False

# %%
df_quantity.dtypes
# Out:
# recipe_id          int64
# ingredient_id      int64
# max_qty          float64
# min_qty          float64
# unit              object
# preparation       object
# optional            bool
# dtype: object

# %% [markdown]
# Again, it seems that all columns are relevant, since in the end we want to be able to show the recipe to the user.

# %% [markdown]
# ### The recipe dataset
# Finally, we have the recipe dataset:

# %%
df_recipe = pd.read_csv('dataset/recipe.csv')
# Set the index to ingredient id.
df_recipe = df_recipe.set_index('recipe_id')
df_recipe.head()
# Out:
#                              title                subtitle  servings  \
# recipe_id
# 214          Raspberry Chiffon Pie                     NaN        10
# 215        Apricot Yogurt Parfaits                     NaN         4
# 216         Fresh Apricot Bavarian                     NaN         8
# 217                  Fresh Peaches  with Banana Cream Whip         4
# 218            Canned Cherry Crisp                     NaN         6
#
#           yield_unit  prep_min  cook_min  stnd_min  \
# recipe_id
# 214            1 pie        20         8       305
# 215              NaN         5         2        65
# 216              NaN         5        13         0
# 217              NaN        10         0         0
# 218              NaN        10         5         0
#
#                                                      source  \
# recipe_id
# 214                     The California Tree Fruit Agreement
# 215        Produce for Better Health Foundation and 5 a Day
# 216                   The California Apricot Advisory Board
# 217        Produce for Better Health Foundation and 5 a Day
# 218                          The Cherry Marketing Institute
#
#                                                        intro  \
# recipe_id
# 214                                                      NaN
# 215                                                      NaN
# 216        Serve in stemmed glasses and top with sliced a...
# 217         For a quick, low-cal dessert, serve this on o...
# 218        Your microwave turns a can of cherry pie filli...
#
#                                                   directions
# recipe_id
# 214         For crust, preheat oven to 375 degrees F.\nIn...
# 215         Drain canned apricots, pour 1/4 cup of the ju...
# 216         Drop apricots into boiling water to cover.  R...
# 217         In a small bowl, beat egg white until foamy. ...
# 218         Pour cherry pie filling into an 8-inch, round...

# %%
df_recipe.dtypes
# Out:
# title         object
# subtitle      object
# servings       int64
# yield_unit    object
# prep_min       int64
# cook_min       int64
# stnd_min       int64
# source        object
# intro         object
# directions    object
# dtype: object

# %% [markdown]
# Just like the nutrients, maybe the person for whom we are recommending the recipes, wants a short cook or prep time. We can for example filter all recipes that take less than 30 minutes in total to create.

# %%
df_recipe_less_than_30_minutes = df_recipe[df_recipe['prep_min'] + df_recipe['cook_min'] < 30]
df_recipe_less_than_30_minutes.head()
# Out:
#                              title                subtitle  servings  \
# recipe_id
# 214          Raspberry Chiffon Pie                     NaN        10
# 215        Apricot Yogurt Parfaits                     NaN         4
# 216         Fresh Apricot Bavarian                     NaN         8
# 217                  Fresh Peaches  with Banana Cream Whip         4
# 218            Canned Cherry Crisp                     NaN         6
#
#           yield_unit  prep_min  cook_min  stnd_min  \
# recipe_id
# 214            1 pie        20         8       305
# 215              NaN         5         2        65
# 216              NaN         5        13         0
# 217              NaN        10         0         0
# 218              NaN        10         5         0
#
#                                                      source  \
# recipe_id
# 214                     The California Tree Fruit Agreement
# 215        Produce for Better Health Foundation and 5 a Day
# 216                   The California Apricot Advisory Board
# 217        Produce for Better Health Foundation and 5 a Day
# 218                          The Cherry Marketing Institute
#
#                                                        intro  \
# recipe_id
# 214                                                      NaN
# 215                                                      NaN
# 216        Serve in stemmed glasses and top with sliced a...
# 217         For a quick, low-cal dessert, serve this on o...
# 218        Your microwave turns a can of cherry pie filli...
#
#                                                   directions
# recipe_id
# 214         For crust, preheat oven to 375 degrees F.\nIn...
# 215         Drain canned apricots, pour 1/4 cup of the ju...
# 216         Drop apricots into boiling water to cover.  R...
# 217         In a small bowl, beat egg white until foamy. ...
# 218         Pour cherry pie filling into an 8-inch, round...

# %% [markdown]
# Now, we only have recipes that take less than 30 minutes in total to create. Why not add total recipe time as a column, and remove `stnd_min`, since I have no idea the column means. Furthermore, the source does not seem relevant for our recommendation system.

# %%
#df_recipe.drop('stnd_min', inplace=True, axis=1)
df_recipe.drop('source', inplace=True, axis=1)
df_recipe.insert(loc=6, column='total_min', value=(df_recipe['prep_min'] + df_recipe['cook_min']))
df_recipe.head()
# Out:
#                              title                subtitle  servings  \
# recipe_id
# 214          Raspberry Chiffon Pie                     NaN        10
# 215        Apricot Yogurt Parfaits                     NaN         4
# 216         Fresh Apricot Bavarian                     NaN         8
# 217                  Fresh Peaches  with Banana Cream Whip         4
# 218            Canned Cherry Crisp                     NaN         6
#
#           yield_unit  prep_min  cook_min  total_min  stnd_min  \
# recipe_id
# 214            1 pie        20         8         28       305
# 215              NaN         5         2          7        65
# 216              NaN         5        13         18         0
# 217              NaN        10         0         10         0
# 218              NaN        10         5         15         0
#
#                                                        intro  \
# recipe_id
# 214                                                      NaN
# 215                                                      NaN
# 216        Serve in stemmed glasses and top with sliced a...
# 217         For a quick, low-cal dessert, serve this on o...
# 218        Your microwave turns a can of cherry pie filli...
#
#                                                   directions
# recipe_id
# 214         For crust, preheat oven to 375 degrees F.\nIn...
# 215         Drain canned apricots, pour 1/4 cup of the ju...
# 216         Drop apricots into boiling water to cover.  R...
# 217         In a small bowl, beat egg white until foamy. ...
# 218         Pour cherry pie filling into an 8-inch, round...

# %% [markdown]
# Let's try joining the recipe and nutrition data sets!

# %%
df_recipe_nutrition = pd.merge(df_recipe, df_nutrition, on='recipe_id', how='inner')
df_recipe_nutrition.head()
# Out:
#                              title                subtitle  servings  \
# recipe_id
# 214          Raspberry Chiffon Pie                     NaN        10
# 215        Apricot Yogurt Parfaits                     NaN         4
# 216         Fresh Apricot Bavarian                     NaN         8
# 217                  Fresh Peaches  with Banana Cream Whip         4
# 218            Canned Cherry Crisp                     NaN         6
#
#           yield_unit  prep_min  cook_min  total_min  stnd_min  \
# recipe_id
# 214            1 pie        20         8         28       305
# 215              NaN         5         2          7        65
# 216              NaN         5        13         18         0
# 217              NaN        10         0         10         0
# 218              NaN        10         5         15         0
#
#                                                        intro  \
# recipe_id
# 214                                                      NaN
# 215                                                      NaN
# 216        Serve in stemmed glasses and top with sliced a...
# 217         For a quick, low-cal dessert, serve this on o...
# 218        Your microwave turns a can of cherry pie filli...
#
#                                                   directions  ...  cholestrl  \
# recipe_id                                                     ...
# 214         For crust, preheat oven to 375 degrees F.\nIn...  ...       1.39
# 215         Drain canned apricots, pour 1/4 cup of the ju...  ...       3.48
# 216         Drop apricots into boiling water to cover.  R...  ...       3.46
# 217         In a small bowl, beat egg white until foamy. ...  ...       0.00
# 218         Pour cherry pie filling into an 8-inch, round...  ...      10.36
#
#            sodium  iron  vitamin_c  vitamin_a  fiber  pcnt_cal_carb  \
# recipe_id
# 214        260.78  0.81       8.89     586.20   0.87          56.80
# 215         46.17  0.57      13.02    2738.24   0.62          67.38
# 216         41.79  0.37       6.13    1521.10   0.34          78.45
# 217         14.01  0.19       8.79     478.09   0.69          88.98
# 218         50.22  0.66       0.16     229.16   1.05          72.81
#
#            pcnt_cal_fat  pcnt_cal_prot  calories
# recipe_id
# 214               35.68           7.53    290.79
# 215                6.89          16.17    141.01
# 216                7.24          14.30    137.06
# 217                2.35           8.67     81.70
# 218               24.46           2.73    201.23
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Export the dataframes

# %%
df_recipe_nutrition.to_csv('export/recipe.csv', encoding='utf-8')
df_quantity.to_csv('export/recipe.csv', encoding='utf-8')
df_ingredient.to_csv('export/recipe.csv', encoding='utf-8')
